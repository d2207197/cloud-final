# %%
from IPython.display import Image
from IPython.display import HTML

def website(url):
    return HTML('<iframe src={} width=800 height=600></iframe>'.format(url))
def image(path):
    return Image(filename=path)

# %% [markdown]
# ## Cloud Programming
#
# # 期末專題 - 語言搜尋引擎
#
# 第 27 組
#
# **顏孜羲**

# %% [markdown]
# # 幾乎每天需求 - 用 Google 學英文、查英文

# %%
image('img/play role.png')

# %%
image('img/a beach.png')

# %% [markdown]
# # 目標
# - 建立一搜尋引擎用於搜尋英文詞語用法。可輔助英語學習與文章寫作。
# - 例如：
#     + 「`adj. beach`」即代表搜尋 beach 前面出現過的形容詞。
#     + 「`play * role`」搜尋 play 合 role 中間最常出現的字詞組合。

# %% [markdown]
# # 需求
# - 超級大的語料庫
# - 高效能，能處理大量資料的 Database
# - 處理 user query 並轉換成 database query 的程式
# - 漂亮的網頁界面

# %% [markdown]
# # 資料來源
#
# - Web1T 5-grams
#     + 24 GB compressed (gzip'ed) text files
#     + contributed by Google
#
# > by love but separated by        67
# > by love can relate to   62
# > by love divine develops the     49
# > by love divine gives the        49
# > by love divine leads to 49

# %% [markdown]
# # 系統建立流程
# 1. 處理 Web1T 5-grams 資料，建立適合 HBase 搜尋之格式，放入 HBase
# 2. 建立搜尋語法解析器，轉換搜尋語法為 HBase 的 query
# 3. 結合網頁界面，用於顯示結果

# %% [markdown]
# # Query 語法
#
# | 語法                   |說明                   |
# | --------------------- |:-------------------------|
# |  -                    |單一任意字詞             |
# | *                     | 零到多個任意字詞         |
# | ?term                 |term 可有可無            |
# | term1 &#124; term2           | term1 或 term2          |
# | adj. det. n. v. prep. | 形容詞、冠詞、名詞、動詞、介繫詞 |
#
# ## 範例
#
# - `adj. beach` 有哪些形容詞用於形容沙灘
# - `go ?to home` go 與 home 之間是否要放 to
# - `play * role|part`
# - `kill the _` 最常被 kill 的東西是

# %%
image('img/linggle.png')

# %%
website('http://aan.linggle.com/#adj.%20beach#CMD')

# %% [markdown]
# ## Database 功能需求
#
# 1. 依據 *任何單詞* 在 *任何位置* 組合搜尋。例如 `'play _ _ role'` 需要搜尋 play 在第一個位置，且，role 在第四個位置。
# 2. 搜尋結果依據 count 排序
#
# ## 已知 HBase 限制
#
# - HBase 僅有單一 indexed 欄位，即 row key。

# %% [markdown]
# ## 關鍵 HBase 特性
#
# - HBase Table 內的所有資料皆以 row key 內容排序(byte order)。
# - HBase 所提供之 scan 可掃描出某個範圍內的 rowkeys。
# - HBase 中執行 scan 或 get 皆可指定 column 值來篩選資料。
#
# ### Schema
# | ROW KEY                  | COLUMN FAMILY **sel**                     |
# | ------------------------ |:------------------------------------------|
# | **selected words**#**count**#**hashcode**               | **sel:size-selector** = **"ngram  count"** |

# %% [markdown]
# ### Schema
# | ROW KEY                  | COLUMN FAMILY **sel**                     |
# | ------------------------ |:------------------------------------------|
# | **selected words**#**count**#**hashcode**               | **sel:size-selector** = **"ngram  count"** |
#
#
# ## 資料輸入範例
#
# 例如如下的 ngram 與 count
#
# `"by love but separated by        67"`
#
# 由於共有五個字，selector 為 [0, 1, 2, 3, 4] 的所有子集合共 31 組（不含空集合）。於是會產生 31 個 row。
#
# | ROW KEY                  | COLUMN FAMILY **sel**                     |
# | ------------------------ |:------------------------------------------|
# | by#67#fe               | sel:5-0  = "by love but separated by  67" |
# | love#67#fe               | sel:5-1  = "by love but separated by  67" |
# | but#67#fe               | sel:5-2  = "by love but separated by  67" |
# | ... | ... |
# | but separated#67#fe    | sel:5-23 = "by love but separated by  67" |
# | by separated#67#fe     | sel:5-03 = "by love but separated by  67" |
# | ... | ... |

# %% [markdown]
# ## Query 語法的對應
#
# | ROW KEY                  | COLUMN FAMILY **sel**                     |
# | ------------------------ |:------------------------------------------|
# | by separated#67#fe     | sel:5-03 = "by love but separated by  67" |
#
#
# 於是利用 HBase 的 Scan 功能
#
# `> scan 'tableName', {COLUMNS => ["sel:5-03"], STARTROW => "by separated", STOPRAW => "by separatee"}`
#
# 這筆資料正巧可對應到此 query: `"by _ _ separated _"`

# %% [markdown]
# ### Schema
# | ROW KEY                  | COLUMN FAMILY **sel**                     |
# | ------------------------ |:------------------------------------------|
# | **selected words**#**count**#**hashcode**               | **sel:size-selector** = **"ngram  count"** |
#
# ## ROW KEY 與 column 設計說明
# - Row key
#     + **selected words**: 對應到 selector 位置的 words，用於 scan 時作為範圍對應。(4 to 20 Bytse)
#     + **count**: 置放在 [selected words] 後方，可使 scan 結果依照 count 排序。(4 Bytes)
#     + **hashcode**: 用於避免 [selected words][count] 重複出現，而覆蓋掉另一筆資料。(4 Bytes)
# - Column
#     + **size-selector**: 5-03 代表資料長度 5，選擇第 0 與 3 個 words。
#
# Row key 的所有欄位皆會轉換成 Byte Array。selected words 會依照預先建立的 map 轉換為數字。

# %% [markdown]
# # Hadoop Streaming
#
# - HBase 資料預處理與輸入程式由 scala 撰寫，但沒有使用 Hadoop MapReduce API。
# - 為了加速資料處理，利用 Hadoop 內建的 Streaming jar 程式，可將任何可執行檔作為 mapper, combiner, reducer。
#
# ```
# $ yarn jar $HADOOP_MAPRED_HOME/hadoop-streaming.jar -help
# Usage: $HADOOP_PREFIX/bin/hadoop jar hadoop-streaming.jar [options]
# Options:
#   -input          <path> DFS input file(s) for the Map step.
#   -output         <path> DFS output directory for the Reduce step.
#   -mapper         <cmd|JavaClassName> Optional. Command to be run as mapper.
#   -combiner       <cmd|JavaClassName> Optional. Command to be run as combiner.
#   -reducer        <cmd|JavaClassName> Optional. Command to be run as reducer.
#   -file           <file> Optional. File/dir to be shipped in the Job jar file.
#                   Deprecated. Use generic option "-files" instead.
#   -inputformat    <TextInputFormat(default)|SequenceFileAsTextInputFormat|JavaClassName>
#                   Optional. The input format class.
#   -outputformat   <TextOutputFormat(default)|JavaClassName>
#                   Optional. The output format class.
#   -partitioner    <JavaClassName>  Optional. The partitioner class.
#    -numReduceTasks <num> Optional. Number of reduce tasks.
#   -inputreader    <spec> Optional. Input recordreader spec.
# ...
# ```

# %% [markdown]
# # Hadoop Streaming 執行範例
#
# ```
# $ yarn jar $HADOOP_MAPRED_HOME/hadoop-streaming.jar  \
#    -files web1t_unigrams_300000up.json,target/scala-2.10/default-assembly-0.1-SNAPSHOT.jar,hbase-site.xml  \
#    -input /corpus/Web1T/2gms,/corpus/Web1T/3gms,/corpus/Web1T/4gms,/corpus/Web1T/5gms \
#    -output putNgram-output \
#    -mapper 'java -jar hbasePutNgram-assembly-0.1-SNAPSHOT.jar web1t_unigrams_300000up.json web1t-linggle'
# ```
#
# - 利用 `-files` 參數將程式執行過程所需的額外檔案上傳。
# - `-input` 指定輸入資料
# - `-output` 指定輸出資料，由於資料直接到 HBase，此 output 僅用來觀察資料
# - `-mapper` 指定 Mapper 指令

# %% [markdown]
# # Hadoop Streaming 優缺點
#
# ## 優
# - 可使用任何語言撰寫 Mapper, Reducer, Combiner。也可使用現成的執行檔，例如 wc, cat, uniq, grep, sort。
# - 可輕鬆 local 測試
# - debug 方便
#
# ## 缺
# - 若不使用 Hadoop MapReduce API 撰寫 Mapper, 將受限在 `<Text, Text>` 資料格式
# - 無法自定 GroupComparator 與 SortComparator。
# - 多 Job 需獨立跑多個 streaming.jar

# %% [markdown]
# # FYI
#
# ## Hadoop Pig
# - 可使用 Streaming
# - 可從外部自定 User-Defined Function(UDF)，支援可編譯成 JVM class 的語言，如 Java, Scala, Jython
# - 可輕鬆 local 測試
# - PigStorage 適合處理複雜格式資料
# - 輕鬆組成多個 MapReduce Job
#
# ## MongoDB v.s. HBase
# - Scaling
# - Performance
# - Query
# - Datatypes

# %%
image('img/hadoop screen.png')

# %%
website('http://lost.nlpweb.org:60010/table.jsp?name=web1t-linggle')
# Out:
# <iframe src=http://lost.nlpweb.org:60010/table.jsp?name=web1t-linggle width=800 height=600></iframe>

# %%
image('img/ganglia.png')

# %%
import hbasengram
# reload( monggle)
web1t = hbasengram.HBaseNgram('lost.nlpweb.org', 'web1t-linggle')   # connect to HBase host = lost.nlpweb.org, table = web1t-linggle

# %%
parser = hbasengram.queryparser()                                   # create a parser
querys = parser.parseString('A * adj. B|C _')[0]                 # parse the query
querys = filter(lambda q: q.length() > 1, querys)
list(querys)
# Out:
# [<r:''\x00\x00\x008\x00\x00\x00\xe7'', t:['A', 'B'], c:sel:4-02, f:[(1, 'adj.')]>,
#  <r:''\x00\x00\x008\x00\x00\x00\x8b'', t:['A', 'C'], c:sel:4-02, f:[(1, 'adj.')]>,
#  <r:''\x00\x00\x008\x00\x00\x00\xe7'', t:['A', 'B'], c:sel:5-03, f:[(2, 'adj.')]>,
#  <r:''\x00\x00\x008\x00\x00\x00\x8b'', t:['A', 'C'], c:sel:5-03, f:[(2, 'adj.')]>]

# %%
web1t.query('A n. to v.', limit= 10)
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-61-e0c284f9085f> in <module>()
# ----> 1 web1t.query('A n. to v.', limit= 10)
#
# /Users/joe/Google Drive/My presents and doc/cloud-final/monggle.py in query(self, query, limit)
#     568             # LOGGER.debug('results: {}'.format(results))
#     569             # return list(islice(self._merge(results), limit))
# --> 570             return list(self._merge(results))
#     571
#     572
#
# /Users/joe/Google Drive/My presents and doc/cloud-final/monggle.py in _merge(self, iterables)
#     445             try:
#     446                 next = it.next
# --> 447                 row = next()
#     448                 row = Row.make_from_hbase(row)
#     449                 h.append([row, filters, itnum, next])
#
# /usr/local/lib/python2.7/site-packages/happybase/table.pyc in scan(self, row_start, row_stop, row_prefix, columns, filter, timestamp, include_timestamp, batch_size, scan_batching, limit, sorted_columns)
#     366             )
#     367             scan_id = self.connection.client.scannerOpenWithScan(
# --> 368                 self.name, scan, {})
#     369
#     370         logger.debug("Opened scanner (id=%d) on '%s'", scan_id, self.name)
#
# /usr/local/lib/python2.7/site-packages/happybase/hbase/Hbase.pyc in scannerOpenWithScan(self, tableName, scan, attributes)
#    1887     """
#    1888     self.send_scannerOpenWithScan(tableName, scan, attributes)
# -> 1889     return self.recv_scannerOpenWithScan()
#    1890
#    1891   def send_scannerOpenWithScan(self, tableName, scan, attributes):
#
# /usr/local/lib/python2.7/site-packages/happybase/hbase/Hbase.pyc in recv_scannerOpenWithScan(self)
#    1900
#    1901   def recv_scannerOpenWithScan(self, ):
# -> 1902     (fname, mtype, rseqid) = self._iprot.readMessageBegin()
#    1903     if mtype == TMessageType.EXCEPTION:
#    1904       x = TApplicationException()
#
# /usr/local/lib/python2.7/site-packages/thrift/protocol/TBinaryProtocol.pyc in readMessageBegin(self)
#     124
#     125   def readMessageBegin(self):
# --> 126     sz = self.readI32()
#     127     if sz < 0:
#     128       version = sz & TBinaryProtocol.VERSION_MASK
#
# /usr/local/lib/python2.7/site-packages/thrift/protocol/TBinaryProtocol.pyc in readI32(self)
#     204
#     205   def readI32(self):
# --> 206     buff = self.trans.readAll(4)
#     207     val, = unpack('!i', buff)
#     208     return val
#
# /usr/local/lib/python2.7/site-packages/thrift/transport/TTransport.pyc in readAll(self, sz)
#      56     have = 0
#      57     while (have < sz):
# ---> 58       chunk = self.read(sz - have)
#      59       have += len(chunk)
#      60       buff += chunk
#
# /usr/local/lib/python2.7/site-packages/thrift/transport/TTransport.pyc in read(self, sz)
#     157       return ret
#     158
# --> 159     self.__rbuf = StringIO(self.__trans.read(max(sz, self.__rbuf_size)))
#     160     return self.__rbuf.read(sz)
#     161
#
# /usr/local/lib/python2.7/site-packages/thrift/transport/TSocket.pyc in read(self, sz)
#     101   def read(self, sz):
#     102     try:
# --> 103       buff = self.handle.recv(sz)
#     104     except socket.error, e:
#     105       if (e.args[0] == errno.ECONNRESET and
#
# error: [Errno 60] Operation timed out

# %% [markdown]
# ## Cloud Programming
#
# # 語言搜尋引擎
#
# 第 27 組
#
# **顏孜羲**
